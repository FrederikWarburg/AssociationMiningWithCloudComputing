# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../results.csv')
print(data)
# Out:
#     support abs   support          time  itemsets  rules
# 0           400  0.017699      0.826737        12      2
# 1           300  0.013274      0.972027        29     12
# 2           200  0.008850      1.889119        71     27
# 3           100  0.004425     56.133838       550    208
# 4            90  0.003982    110.323015       773    299
# 5            80  0.003540    193.253462      1101    433
# 6            70  0.003097    446.506165      1645    661
# 7            60  0.002655    817.453867      2591   1004
# 8            50  0.002212   2214.435480      4558   1630
# 9            40  0.001770   7053.584308      8862   2973
# 10           30  0.001327  22616.893377     20570   6282

# %%
[key for key in data]
# Out:
# ['support abs', 'support', 'time', 'itemsets', 'rules']

# %%
plt.plot(data['support abs'], data['time'])
plt.xlabel('Support')
plt.ylabel('Seconds')
plt.show()

# %%
plt.plot(data['support abs'], data['itemsets'],label='#Itemsets')
plt.plot(data['support abs'], data['rules'], label='#Rules')
plt.legend()
plt.xlabel('Support')
plt.ylabel('# Obs')
plt.show()
